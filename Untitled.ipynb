# %% [markdown]
# # Machine Learning
#
# ## Title - Understanding Support Vector Machines: How Kernel Functions Shape Decision Boundaries
#
# Github - https://github.com/Abhilash2330/Machine-Learning/tree/main

# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

plt.style.use("seaborn-v0_8")

# %% [markdown]
# ### Load Breast Cancer Dataset

# %%
cancer = datasets.load_breast_cancer()

df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
df["target"] = cancer.target

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (569, 31)
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
# ...

# %% [markdown]
# ### Feature Selection

# %%
# Select two features for visualization

X = df[["mean radius", "mean texture"]].values
y = df["target"].values

# %%
plt.figure(figsize=(7,5))

plt.scatter(
    X[:,0],
    X[:,1],
    c=y,
    edgecolor="k"
)

plt.xlabel("Mean Radius")
plt.ylabel("Mean Texture")
plt.title("Original Data Distribution (Before Scaling)")

plt.savefig("original_data_distribution.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### Feature Scaling

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 398
# Testing samples: 171

# %% [markdown]
# ### Train SVM Models

# %%
svm_linear = SVC(kernel="linear", C=1)
svm_poly = SVC(kernel="poly", degree=3, C=1)
svm_rbf = SVC(kernel="rbf", gamma="scale", C=1)

svm_linear.fit(X_train, y_train)
svm_poly.fit(X_train, y_train)
svm_rbf.fit(X_train, y_train)
# Out:
# SVC(C=1)

# %% [markdown]
# ### Model Evaluation

# %%
models = {
    "Linear Kernel": svm_linear,
    "Polynomial Kernel": svm_poly,
    "RBF Kernel": svm_rbf
}

for name, model in models.items():

    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)

    print("\n=========================================================")
    print(name)
    print("Accuracy:", round(acc,3))
    print(classification_report(y_test, y_pred))
# Out:
# ...
# Linear Kernel
# Accuracy: 0.871
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82        64
#            1       0.87      0.93      0.90       107
#
#     accuracy                           0.87       171
#    macro avg       0.87      0.85      0.86       171
# weighted avg       0.87      0.87      0.87       171
#
#
# ...
# Polynomial Kernel
# Accuracy: 0.825
#               precision    recall  f1-score   support
#
#            0       1.00      0.53      0.69        64
#            1       0.78      1.00      0.88       107
#
#     accuracy                           0.82       171
#    macro avg       0.89      0.77      0.79       171
# weighted avg       0.86      0.82      0.81       171
#
#
# ...
# RBF Kernel
# Accuracy: 0.883
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84        64
#            1       0.89      0.93      0.91       107
#
# ...

# %% [markdown]
# ### Decision Boundary function

# %%
def plot_decision_boundary(model, X, y, title, filename):

    x_min, x_max = X[:,0].min() - 1, X[:,0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1

    xx, yy = np.meshgrid(
        np.linspace(x_min, x_max, 300),
        np.linspace(y_min, y_max, 300)
    )

    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(7,5))

    plt.contourf(xx, yy, Z, alpha=0.3)

    plt.scatter(
        X[:,0],
        X[:,1],
        c=y,
        edgecolor="k"
    )

    plt.xlabel("Mean Radius (Scaled)")
    plt.ylabel("Mean Texture (Scaled)")
    plt.title(title)

    plt.savefig(filename, dpi=300, bbox_inches="tight")

    plt.show()

# %% [markdown]
# ### Decision Boundary Plots

# %%
plot_decision_boundary(
    svm_linear,
    X_scaled,
    y,
    "SVM Decision Boundary (Linear Kernel)",
    "svm_linear_kernel.png"
)

plot_decision_boundary(
    svm_poly,
    X_scaled,
    y,
    "SVM Decision Boundary (Polynomial Kernel)",
    "svm_polynomial_kernel.png"
)

plot_decision_boundary(
    svm_rbf,
    X_scaled,
    y,
    "SVM Decision Boundary (RBF Kernel)",
    "svm_rbf_kernel.png"
)

# %% [markdown]
# ### Model Metrics

# %%
models = {
    "Linear Kernel": svm_linear,
    "Polynomial Kernel": svm_poly,
    "RBF Kernel": svm_rbf
}

results = []

for name, model in models.items():

    pred = model.predict(X_test)

    acc = accuracy_score(y_test, pred)
    prec = precision_score(y_test, pred)
    rec = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    results.append([name, acc, prec, rec, f1])

results_df = pd.DataFrame(
    results,
    columns=["Model","Accuracy","Precision","Recall","F1 Score"]
)

results_df
# Out:
#                Model  Accuracy  Precision    Recall  F1 Score
# 0      Linear Kernel  0.871345   0.869565  0.934579  0.900901
# 1  Polynomial Kernel  0.824561   0.781022  1.000000  0.877049
# 2         RBF Kernel  0.883041   0.891892  0.925234  0.908257

# %%
fig, ax = plt.subplots(figsize=(8,3))

ax.axis("tight")
ax.axis("off")

table = ax.table(
    cellText=np.round(results_df.iloc[:,1:].values,3),
    colLabels=results_df.columns[1:],
    rowLabels=results_df["Model"],
    loc="center"
)

table.scale(1.2,1.5)

plt.title("Performance Comparison of SVM Kernels")

plt.savefig("svm_kernel_accuracy_table.png", dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### Accuracy Comparison plot

# %%
plt.figure(figsize=(7,4))

plt.bar(results_df["Model"], results_df["Accuracy"])

plt.ylabel("Accuracy")
plt.title("Accuracy Comparison of SVM Kernels")

plt.savefig("svm_kernel_accuracy_bar.png", dpi=300, bbox_inches="tight")

plt.show()
